# %%
import requests
import pandas as pd
import chromedriver_binary
import time
from selenium import webdriver
from bs4 import BeautifulSoup

link = 'https://stock-pictures.netlify.app'

# %%
link = 'https://stock-pictures.netlify.app/'
res = requests.get(link)
soup = BeautifulSoup(res.text,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><link href="/favicon.ico" rel="icon"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="#000000" name="theme-color"/><meta content="Web site created using create-react-app" name="description"/><link href="/logo192.png" rel="apple-touch-icon"/><link href="/manifest.json" rel="manifest"/><title>Stock Images</title><script defer="defer" src="/static/js/main.67034cee.js"></script><link href="/static/css/main.07ec7845.css" rel="stylesheet"/></head><body><noscript>You need to enable JavaScript to run this app.</noscript><div id="root"></div></body></html>

# %%
driver = webdriver.Chrome()

# %%
driver.get(link)

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
print(soup.find_all('img').get('src'))
# data = [ ]
# time.sleep(15)
# for sp in soup.find_all('div', class_ = 'container'):

#     if('gif' not in sp.find('img').get('src')):
        
#         link = sp.find('img').get('src')
#         tags = list(set(sp.find('div',class_ = 'tags').text[7:].split(' ')))
        
#         likes    = int(sp.find('div',class_ = 'likes-comments').find_all('span')[0].text[:-6])
#         comments = int(sp.find('div',class_ = 'likes-comments').find_all('span')[1].text[:-9])
        
#         data.append([link, ' '.join(tags), likes, comments])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(soup.find_all('img').get('src'))
#       2 # data = [ ]
#       3 # time.sleep(15)
#       4 # for sp in soup.find_all('div', class_ = 'container'):
#    (...)
#      13
#      14 #         data.append([link, ' '.join(tags), likes, comments])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\bs4\element.py:2428, in ResultSet.__getattr__(self, key)
#    2426 def __getattr__(self, key):
#    2427     """Raise a helpful exception to explain a common code fix."""
# -> 2428     raise AttributeError(
#    2429         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2430     )
#
# AttributeError: ResultSet object has no attribute 'get'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
data = [ ]
time.sleep(15)
for sp in soup.find_all('div', class_ = 'container'):

    if('gif' not in sp.find('img').get('src')):
        
        link = sp.find('img').get('src')
        tags = list(set(sp.find('div',class_ = 'tags').text[7:].split(' ')))
        
        likes    = int(sp.find('div',class_ = 'likes-comments').find_all('span')[0].text[:-6])
        comments = int(sp.find('div',class_ = 'likes-comments').find_all('span')[1].text[:-9])
        
        data.append([link, ' '.join(tags), likes, comments])

# %%
df = pd.DataFrame(data, columns = ['link','tags','likes','comments'])
df
# df.head()
# Out:
#                                                  link  \
# 0   https://cdn.pixabay.com/photo/2022/03/06/05/30...
# 1   https://cdn.pixabay.com/photo/2022/04/07/11/45...
# 2   https://cdn.pixabay.com/photo/2022/02/28/15/28...
# 3   https://cdn.pixabay.com/photo/2022/04/04/02/52...
# 4   https://cdn.pixabay.com/photo/2022/04/09/18/06...
#
#                                                  tags  likes  comments
# 0                   Blue Sky, Clouds, Atmosphere, Sky    196        55
# 1                      Ornithology, Hummingbird Bird,     76        20
# 2                 Sea, Subtropical Rainbow, Rainfall,    282       106
# 3                Sakura Japan, Road, Cherry Blossoms,     42        11
# 4                      Plant Marguerite, Cape Flower,     39        15
# 5                        Relaxing Under Tree The Rest    522       108
# 6                       Cottontail Grass Wild Rabbit,     51        10
# 7                      Flowers, Crocus, Plant Spring,    135        44
# 8                Table Vacation, Coffee, Drink, Café,     26         5
# 9                Fall, Waterfall, Epic, Nature, Light     96        21
# 10              Nature Field, Morning, Sunrise, Dawn,    807       131
# 11                  Animal Birdwatching, Robin, Bird,     69        19
# 12             Soil, Seedlings, Spring Bloom Flowers,     42         9
# 13                  Hills Highway, Countryside, Road,     53        14
# 14                Bridge, Cityscape, Monochrome, City     45        13
# 15             Sakura, Water Cherry Blossoms, Spring,     70        12
# 16            Eggs, Art Template, Background, Easter,      5         2
# 17            Species Ornithology, Chat, Indian Bird,    171        53
# 18               Town, Night, Winter, Season Village,    109        15
# 19               Pansy, Viola, Flower, Bloom Blossom,     55        36
# 20                Vacations Architecture, Lake, Port,    276        49
# 21                         Flowers, Sunflowers, Plant     54        21
# 22                   Flowers, Coffee, Spring, Morning     40        10
# 23                 Peak, Lake, Wanaka, Roys Mountains     69        19
# 24  you many likes. everyone. for downloads and Th...    197         0
# 25               Outdoors, Nature, Beach, Exploration    272       150
# 26  Shot of sunset. Danish during Coast Jutland. T...     48        11
# 27                       Animal Gentoo Bird, Penguin,     93        22
# 28           Lantern, Beach, Sea, Water, Heaven, Tree    243        31
# 29                       Bunny Easter Spring, Easter,     17        10
# 30  rock on green formation lake during trees dayt...   3098       495
# 31           Travel Eiffel Tower, Tourist Attraction,     83        21
# 32            Menhir, Clouds, Standing Stones, Stones     64        49
# 33             Winter, Frost, Snow, Road, Path Trees,    133        24
# 34                                   Bird, Woodpecker     28        20
# 35              Tape, Classic Cassette, Retro, Music,    134        20
# 36                  Wind Clouds, Power Energy, Mills,    144       101
# 37            Piran Tourism, Square, Travel, Tartini,     70        19
# 38                    Eggs, Nest, Eggs Easter Colored     29         0
# 39           Travel Outdoors, Winter, Nature, Season,    111        24
# 40           Dying Glacier, Melting Glaciers, Glacier     36        27
# 41            Forest, Jungle, Nature Green, Tropical,    135        22
# 42              Petals Tulip, Flower, Blossom, Bloom,     92        35
# 43                               Flowers, Pink Petals     62         0
# 44                 Passiflora, Flower, Flower Passion     97        66
# 45            Faith, Blessing Religion, Hope, Prayer,    175        57
# 46              Space, Cosmos Galaxy, Universe, Star,     45        40
# 47                   Macro Nature, Dragonfly, Insect,     19         3

# %%
df.to_csv('data.csv', index = False)
